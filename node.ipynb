# %%
class Node:
    def __init__(self, row, col):
        self.row = row
        self.col = col
        self.is_wall = False
        self.g = float("inf")
        self.h = 0
        self.f = float("inf")
        self.parent = None
